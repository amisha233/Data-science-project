# %% [markdown]
# <a href="https://colab.research.google.com/github/amisha233/Data-science-project/blob/main/linear_Regression_LSM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
x=[171,151,124,134,156]
y=[80,60,45,50,65]
plt.scatter(x,y ,label='scatter plot')
plt.xlabel('x')
plt.ylabel('y')
plt.title('scatter plot')
plt.show()
